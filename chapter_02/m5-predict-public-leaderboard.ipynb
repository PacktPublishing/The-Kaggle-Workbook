# %%
import numpy as np
import pandas as pd
import os
import random
import math
from decimal import Decimal as dec
import datetime
import time
import gc
import lightgbm as lgb
import pickle

import warnings
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
store_id_set_list = ['CA_1', 'CA_2', 'CA_3', 'CA_4', 'TX_1', 'TX_2', 'TX_3', 'WI_1', 'WI_2', 'WI_3']
end_train_day_x_list = [1913]
prediction_horizon_list = [7, 14, 21, 28]

pred_v_all_df = list()

for end_train_day_x in end_train_day_x_list:
    previous_prediction_horizon = 0
    for prediction_horizon in prediction_horizon_list:
        notebook_name = f"../input/m5-train-day-{end_train_day_x}-horizon-{prediction_horizon}"

        pred_v_df = pd.DataFrame()
        
        for store_index, store_id in enumerate(store_id_set_list):
            
            model_path = str(f'{notebook_name}/lgb_model_{store_id}_{prediction_horizon}.bin')
            print(f'loading {model_path}')
            estimator = pickle.load(open(model_path, 'rb'))
            base_test = pd.read_feather(f"{notebook_name}/test_{store_id}_{prediction_horizon}.feather")
            enable_features = [col for col in base_test.columns if col not in ['id', 'd', 'sales']]
            
            for predict_day in range(previous_prediction_horizon + 1, prediction_horizon + 1):
                print('[{3} -> {4}] predict {0}/{1} {2} day {5}'.format(
                store_index + 1, len(store_id_set_list), store_id,
                previous_prediction_horizon + 1, prediction_horizon, predict_day))
                mask = base_test['d'] == (end_train_day_x + predict_day)
                base_test.loc[mask, 'sales'] = estimator.predict(base_test[mask][enable_features])
                
            temp_v_df = base_test[
                    (base_test['d'] >= end_train_day_x + previous_prediction_horizon + 1) &
                    (base_test['d'] < end_train_day_x + prediction_horizon + 1)
                    ][['id', 'd', 'sales']]
            
            if len(pred_v_df)!=0:
                pred_v_df = pd.concat([pred_v_df, temp_v_df])
            else:
                pred_v_df = temp_v_df.copy()
            
            del(temp_v_df)
            gc.collect()
        
        previous_prediction_horizon = prediction_horizon
        
        if end_train_day_x == 1913:
            pred_v_df.id = pred_v_df.id.str.replace("evaluation", "validation")
            
        pred_v_all_df.append(pred_v_df)
    
pred_v_all_df = pd.concat(pred_v_all_df)
# Out:
# loading ../input/m5-train-day-1913-horizon-7/lgb_model_CA_1_7.bin
# [1 -> 7] predict 1/10 CA_1 day 1
# [1 -> 7] predict 1/10 CA_1 day 2
# [1 -> 7] predict 1/10 CA_1 day 3
# [1 -> 7] predict 1/10 CA_1 day 4
# [1 -> 7] predict 1/10 CA_1 day 5
# [1 -> 7] predict 1/10 CA_1 day 6
# [1 -> 7] predict 1/10 CA_1 day 7
# loading ../input/m5-train-day-1913-horizon-7/lgb_model_CA_2_7.bin
# [1 -> 7] predict 2/10 CA_2 day 1
# [1 -> 7] predict 2/10 CA_2 day 2
# [1 -> 7] predict 2/10 CA_2 day 3
# [1 -> 7] predict 2/10 CA_2 day 4
# [1 -> 7] predict 2/10 CA_2 day 5
# [1 -> 7] predict 2/10 CA_2 day 6
# [1 -> 7] predict 2/10 CA_2 day 7
# loading ../input/m5-train-day-1913-horizon-7/lgb_model_CA_3_7.bin
# [1 -> 7] predict 3/10 CA_3 day 1
# [1 -> 7] predict 3/10 CA_3 day 2
# [1 -> 7] predict 3/10 CA_3 day 3
# [1 -> 7] predict 3/10 CA_3 day 4
# [1 -> 7] predict 3/10 CA_3 day 5
# [1 -> 7] predict 3/10 CA_3 day 6
# [1 -> 7] predict 3/10 CA_3 day 7
# loading ../input/m5-train-day-1913-horizon-7/lgb_model_CA_4_7.bin
# [1 -> 7] predict 4/10 CA_4 day 1
# [1 -> 7] predict 4/10 CA_4 day 2
# [1 -> 7] predict 4/10 CA_4 day 3
# [1 -> 7] predict 4/10 CA_4 day 4
# [1 -> 7] predict 4/10 CA_4 day 5
# [1 -> 7] predict 4/10 CA_4 day 6
# [1 -> 7] predict 4/10 CA_4 day 7
# loading ../input/m5-train-day-1913-horizon-7/lgb_model_TX_1_7.bin
# [1 -> 7] predict 5/10 TX_1 day 1
# [1 -> 7] predict 5/10 TX_1 day 2
# [1 -> 7] predict 5/10 TX_1 day 3
# [1 -> 7] predict 5/10 TX_1 day 4
# [1 -> 7] predict 5/10 TX_1 day 5
# [1 -> 7] predict 5/10 TX_1 day 6
# [1 -> 7] predict 5/10 TX_1 day 7
# loading ../input/m5-train-day-1913-horizon-7/lgb_model_TX_2_7.bin
# [1 -> 7] predict 6/10 TX_2 day 1
# [1 -> 7] predict 6/10 TX_2 day 2
# [1 -> 7] predict 6/10 TX_2 day 3
# [1 -> 7] predict 6/10 TX_2 day 4
# [1 -> 7] predict 6/10 TX_2 day 5
# [1 -> 7] predict 6/10 TX_2 day 6
# [1 -> 7] predict 6/10 TX_2 day 7
# loading ../input/m5-train-day-1913-horizon-7/lgb_model_TX_3_7.bin
# [1 -> 7] predict 7/10 TX_3 day 1
# [1 -> 7] predict 7/10 TX_3 day 2
# [1 -> 7] predict 7/10 TX_3 day 3
# [1 -> 7] predict 7/10 TX_3 day 4
# [1 -> 7] predict 7/10 TX_3 day 5
# [1 -> 7] predict 7/10 TX_3 day 6
# [1 -> 7] predict 7/10 TX_3 day 7
# loading ../input/m5-train-day-1913-horizon-7/lgb_model_WI_1_7.bin
# [1 -> 7] predict 8/10 WI_1 day 1
# [1 -> 7] predict 8/10 WI_1 day 2
# [1 -> 7] predict 8/10 WI_1 day 3
# [1 -> 7] predict 8/10 WI_1 day 4
# [1 -> 7] predict 8/10 WI_1 day 5
# [1 -> 7] predict 8/10 WI_1 day 6
# [1 -> 7] predict 8/10 WI_1 day 7
# loading ../input/m5-train-day-1913-horizon-7/lgb_model_WI_2_7.bin
# [1 -> 7] predict 9/10 WI_2 day 1
# [1 -> 7] predict 9/10 WI_2 day 2
# [1 -> 7] predict 9/10 WI_2 day 3
# [1 -> 7] predict 9/10 WI_2 day 4
# [1 -> 7] predict 9/10 WI_2 day 5
# [1 -> 7] predict 9/10 WI_2 day 6
# [1 -> 7] predict 9/10 WI_2 day 7
# loading ../input/m5-train-day-1913-horizon-7/lgb_model_WI_3_7.bin
# [1 -> 7] predict 10/10 WI_3 day 1
# [1 -> 7] predict 10/10 WI_3 day 2
# [1 -> 7] predict 10/10 WI_3 day 3
# [1 -> 7] predict 10/10 WI_3 day 4
# [1 -> 7] predict 10/10 WI_3 day 5
# [1 -> 7] predict 10/10 WI_3 day 6
# [1 -> 7] predict 10/10 WI_3 day 7
# loading ../input/m5-train-day-1913-horizon-14/lgb_model_CA_1_14.bin
# [8 -> 14] predict 1/10 CA_1 day 8
# [8 -> 14] predict 1/10 CA_1 day 9
# [8 -> 14] predict 1/10 CA_1 day 10
# [8 -> 14] predict 1/10 CA_1 day 11
# [8 -> 14] predict 1/10 CA_1 day 12
# [8 -> 14] predict 1/10 CA_1 day 13
# [8 -> 14] predict 1/10 CA_1 day 14
# loading ../input/m5-train-day-1913-horizon-14/lgb_model_CA_2_14.bin
# [8 -> 14] predict 2/10 CA_2 day 8
# [8 -> 14] predict 2/10 CA_2 day 9
# [8 -> 14] predict 2/10 CA_2 day 10
# [8 -> 14] predict 2/10 CA_2 day 11
# [8 -> 14] predict 2/10 CA_2 day 12
# [8 -> 14] predict 2/10 CA_2 day 13
# [8 -> 14] predict 2/10 CA_2 day 14
# loading ../input/m5-train-day-1913-horizon-14/lgb_model_CA_3_14.bin
# [8 -> 14] predict 3/10 CA_3 day 8
# [8 -> 14] predict 3/10 CA_3 day 9
# [8 -> 14] predict 3/10 CA_3 day 10
# [8 -> 14] predict 3/10 CA_3 day 11
# [8 -> 14] predict 3/10 CA_3 day 12
# [8 -> 14] predict 3/10 CA_3 day 13
# [8 -> 14] predict 3/10 CA_3 day 14
# loading ../input/m5-train-day-1913-horizon-14/lgb_model_CA_4_14.bin
# [8 -> 14] predict 4/10 CA_4 day 8
# [8 -> 14] predict 4/10 CA_4 day 9
# [8 -> 14] predict 4/10 CA_4 day 10
# [8 -> 14] predict 4/10 CA_4 day 11
# [8 -> 14] predict 4/10 CA_4 day 12
# [8 -> 14] predict 4/10 CA_4 day 13
# [8 -> 14] predict 4/10 CA_4 day 14
# loading ../input/m5-train-day-1913-horizon-14/lgb_model_TX_1_14.bin
# [8 -> 14] predict 5/10 TX_1 day 8
# [8 -> 14] predict 5/10 TX_1 day 9
# [8 -> 14] predict 5/10 TX_1 day 10
# [8 -> 14] predict 5/10 TX_1 day 11
# [8 -> 14] predict 5/10 TX_1 day 12
# [8 -> 14] predict 5/10 TX_1 day 13
# [8 -> 14] predict 5/10 TX_1 day 14
# loading ../input/m5-train-day-1913-horizon-14/lgb_model_TX_2_14.bin
# [8 -> 14] predict 6/10 TX_2 day 8
# [8 -> 14] predict 6/10 TX_2 day 9
# [8 -> 14] predict 6/10 TX_2 day 10
# [8 -> 14] predict 6/10 TX_2 day 11
# [8 -> 14] predict 6/10 TX_2 day 12
# [8 -> 14] predict 6/10 TX_2 day 13
# [8 -> 14] predict 6/10 TX_2 day 14
# loading ../input/m5-train-day-1913-horizon-14/lgb_model_TX_3_14.bin
# [8 -> 14] predict 7/10 TX_3 day 8
# [8 -> 14] predict 7/10 TX_3 day 9
# [8 -> 14] predict 7/10 TX_3 day 10
# [8 -> 14] predict 7/10 TX_3 day 11
# [8 -> 14] predict 7/10 TX_3 day 12
# [8 -> 14] predict 7/10 TX_3 day 13
# [8 -> 14] predict 7/10 TX_3 day 14
# loading ../input/m5-train-day-1913-horizon-14/lgb_model_WI_1_14.bin
# [8 -> 14] predict 8/10 WI_1 day 8
# [8 -> 14] predict 8/10 WI_1 day 9
# [8 -> 14] predict 8/10 WI_1 day 10
# [8 -> 14] predict 8/10 WI_1 day 11
# [8 -> 14] predict 8/10 WI_1 day 12
# [8 -> 14] predict 8/10 WI_1 day 13
# [8 -> 14] predict 8/10 WI_1 day 14
# loading ../input/m5-train-day-1913-horizon-14/lgb_model_WI_2_14.bin
# [8 -> 14] predict 9/10 WI_2 day 8
# [8 -> 14] predict 9/10 WI_2 day 9
# [8 -> 14] predict 9/10 WI_2 day 10
# [8 -> 14] predict 9/10 WI_2 day 11
# [8 -> 14] predict 9/10 WI_2 day 12
# [8 -> 14] predict 9/10 WI_2 day 13
# [8 -> 14] predict 9/10 WI_2 day 14
# loading ../input/m5-train-day-1913-horizon-14/lgb_model_WI_3_14.bin
# [8 -> 14] predict 10/10 WI_3 day 8
# [8 -> 14] predict 10/10 WI_3 day 9
# [8 -> 14] predict 10/10 WI_3 day 10
# [8 -> 14] predict 10/10 WI_3 day 11
# [8 -> 14] predict 10/10 WI_3 day 12
# [8 -> 14] predict 10/10 WI_3 day 13
# [8 -> 14] predict 10/10 WI_3 day 14
# loading ../input/m5-train-day-1913-horizon-21/lgb_model_CA_1_21.bin
# [15 -> 21] predict 1/10 CA_1 day 15
# [15 -> 21] predict 1/10 CA_1 day 16
# [15 -> 21] predict 1/10 CA_1 day 17
# [15 -> 21] predict 1/10 CA_1 day 18
# [15 -> 21] predict 1/10 CA_1 day 19
# [15 -> 21] predict 1/10 CA_1 day 20
# [15 -> 21] predict 1/10 CA_1 day 21
# loading ../input/m5-train-day-1913-horizon-21/lgb_model_CA_2_21.bin
# [15 -> 21] predict 2/10 CA_2 day 15
# [15 -> 21] predict 2/10 CA_2 day 16
# [15 -> 21] predict 2/10 CA_2 day 17
# [15 -> 21] predict 2/10 CA_2 day 18
# [15 -> 21] predict 2/10 CA_2 day 19
# [15 -> 21] predict 2/10 CA_2 day 20
# [15 -> 21] predict 2/10 CA_2 day 21
# loading ../input/m5-train-day-1913-horizon-21/lgb_model_CA_3_21.bin
# [15 -> 21] predict 3/10 CA_3 day 15
# [15 -> 21] predict 3/10 CA_3 day 16
# [15 -> 21] predict 3/10 CA_3 day 17
# [15 -> 21] predict 3/10 CA_3 day 18
# [15 -> 21] predict 3/10 CA_3 day 19
# [15 -> 21] predict 3/10 CA_3 day 20
# [15 -> 21] predict 3/10 CA_3 day 21
# loading ../input/m5-train-day-1913-horizon-21/lgb_model_CA_4_21.bin
# [15 -> 21] predict 4/10 CA_4 day 15
# [15 -> 21] predict 4/10 CA_4 day 16
# [15 -> 21] predict 4/10 CA_4 day 17
# [15 -> 21] predict 4/10 CA_4 day 18
# [15 -> 21] predict 4/10 CA_4 day 19
# [15 -> 21] predict 4/10 CA_4 day 20
# [15 -> 21] predict 4/10 CA_4 day 21
# loading ../input/m5-train-day-1913-horizon-21/lgb_model_TX_1_21.bin
# [15 -> 21] predict 5/10 TX_1 day 15
# [15 -> 21] predict 5/10 TX_1 day 16
# [15 -> 21] predict 5/10 TX_1 day 17
# [15 -> 21] predict 5/10 TX_1 day 18
# [15 -> 21] predict 5/10 TX_1 day 19
# [15 -> 21] predict 5/10 TX_1 day 20
# [15 -> 21] predict 5/10 TX_1 day 21
# loading ../input/m5-train-day-1913-horizon-21/lgb_model_TX_2_21.bin
# [15 -> 21] predict 6/10 TX_2 day 15
# [15 -> 21] predict 6/10 TX_2 day 16
# [15 -> 21] predict 6/10 TX_2 day 17
# [15 -> 21] predict 6/10 TX_2 day 18
# [15 -> 21] predict 6/10 TX_2 day 19
# [15 -> 21] predict 6/10 TX_2 day 20
# [15 -> 21] predict 6/10 TX_2 day 21
# loading ../input/m5-train-day-1913-horizon-21/lgb_model_TX_3_21.bin
# [15 -> 21] predict 7/10 TX_3 day 15
# [15 -> 21] predict 7/10 TX_3 day 16
# [15 -> 21] predict 7/10 TX_3 day 17
# [15 -> 21] predict 7/10 TX_3 day 18
# [15 -> 21] predict 7/10 TX_3 day 19
# [15 -> 21] predict 7/10 TX_3 day 20
# [15 -> 21] predict 7/10 TX_3 day 21
# loading ../input/m5-train-day-1913-horizon-21/lgb_model_WI_1_21.bin
# [15 -> 21] predict 8/10 WI_1 day 15
# [15 -> 21] predict 8/10 WI_1 day 16
# [15 -> 21] predict 8/10 WI_1 day 17
# [15 -> 21] predict 8/10 WI_1 day 18
# [15 -> 21] predict 8/10 WI_1 day 19
# [15 -> 21] predict 8/10 WI_1 day 20
# [15 -> 21] predict 8/10 WI_1 day 21
# loading ../input/m5-train-day-1913-horizon-21/lgb_model_WI_2_21.bin
# [15 -> 21] predict 9/10 WI_2 day 15
# [15 -> 21] predict 9/10 WI_2 day 16
# [15 -> 21] predict 9/10 WI_2 day 17
# [15 -> 21] predict 9/10 WI_2 day 18
# [15 -> 21] predict 9/10 WI_2 day 19
# [15 -> 21] predict 9/10 WI_2 day 20
# [15 -> 21] predict 9/10 WI_2 day 21
# loading ../input/m5-train-day-1913-horizon-21/lgb_model_WI_3_21.bin
# [15 -> 21] predict 10/10 WI_3 day 15
# [15 -> 21] predict 10/10 WI_3 day 16
# [15 -> 21] predict 10/10 WI_3 day 17
# [15 -> 21] predict 10/10 WI_3 day 18
# [15 -> 21] predict 10/10 WI_3 day 19
# [15 -> 21] predict 10/10 WI_3 day 20
# [15 -> 21] predict 10/10 WI_3 day 21
# loading ../input/m5-train-day-1913-horizon-28/lgb_model_CA_1_28.bin
# [22 -> 28] predict 1/10 CA_1 day 22
# [22 -> 28] predict 1/10 CA_1 day 23
# [22 -> 28] predict 1/10 CA_1 day 24
# [22 -> 28] predict 1/10 CA_1 day 25
# [22 -> 28] predict 1/10 CA_1 day 26
# [22 -> 28] predict 1/10 CA_1 day 27
# [22 -> 28] predict 1/10 CA_1 day 28
# loading ../input/m5-train-day-1913-horizon-28/lgb_model_CA_2_28.bin
# [22 -> 28] predict 2/10 CA_2 day 22
# [22 -> 28] predict 2/10 CA_2 day 23
# [22 -> 28] predict 2/10 CA_2 day 24
# [22 -> 28] predict 2/10 CA_2 day 25
# [22 -> 28] predict 2/10 CA_2 day 26
# [22 -> 28] predict 2/10 CA_2 day 27
# [22 -> 28] predict 2/10 CA_2 day 28
# loading ../input/m5-train-day-1913-horizon-28/lgb_model_CA_3_28.bin
# [22 -> 28] predict 3/10 CA_3 day 22
# [22 -> 28] predict 3/10 CA_3 day 23
# [22 -> 28] predict 3/10 CA_3 day 24
# [22 -> 28] predict 3/10 CA_3 day 25
# [22 -> 28] predict 3/10 CA_3 day 26
# [22 -> 28] predict 3/10 CA_3 day 27
# [22 -> 28] predict 3/10 CA_3 day 28
# loading ../input/m5-train-day-1913-horizon-28/lgb_model_CA_4_28.bin
# [22 -> 28] predict 4/10 CA_4 day 22
# [22 -> 28] predict 4/10 CA_4 day 23
# [22 -> 28] predict 4/10 CA_4 day 24
# [22 -> 28] predict 4/10 CA_4 day 25
# [22 -> 28] predict 4/10 CA_4 day 26
# [22 -> 28] predict 4/10 CA_4 day 27
# [22 -> 28] predict 4/10 CA_4 day 28
# loading ../input/m5-train-day-1913-horizon-28/lgb_model_TX_1_28.bin
# [22 -> 28] predict 5/10 TX_1 day 22
# [22 -> 28] predict 5/10 TX_1 day 23
# [22 -> 28] predict 5/10 TX_1 day 24
# [22 -> 28] predict 5/10 TX_1 day 25
# [22 -> 28] predict 5/10 TX_1 day 26
# [22 -> 28] predict 5/10 TX_1 day 27
# [22 -> 28] predict 5/10 TX_1 day 28
# loading ../input/m5-train-day-1913-horizon-28/lgb_model_TX_2_28.bin
# [22 -> 28] predict 6/10 TX_2 day 22
# [22 -> 28] predict 6/10 TX_2 day 23
# [22 -> 28] predict 6/10 TX_2 day 24
# [22 -> 28] predict 6/10 TX_2 day 25
# [22 -> 28] predict 6/10 TX_2 day 26
# [22 -> 28] predict 6/10 TX_2 day 27
# [22 -> 28] predict 6/10 TX_2 day 28
# loading ../input/m5-train-day-1913-horizon-28/lgb_model_TX_3_28.bin
# [22 -> 28] predict 7/10 TX_3 day 22
# [22 -> 28] predict 7/10 TX_3 day 23
# [22 -> 28] predict 7/10 TX_3 day 24
# [22 -> 28] predict 7/10 TX_3 day 25
# [22 -> 28] predict 7/10 TX_3 day 26
# [22 -> 28] predict 7/10 TX_3 day 27
# [22 -> 28] predict 7/10 TX_3 day 28
# loading ../input/m5-train-day-1913-horizon-28/lgb_model_WI_1_28.bin
# [22 -> 28] predict 8/10 WI_1 day 22
# [22 -> 28] predict 8/10 WI_1 day 23
# [22 -> 28] predict 8/10 WI_1 day 24
# [22 -> 28] predict 8/10 WI_1 day 25
# [22 -> 28] predict 8/10 WI_1 day 26
# [22 -> 28] predict 8/10 WI_1 day 27
# [22 -> 28] predict 8/10 WI_1 day 28
# loading ../input/m5-train-day-1913-horizon-28/lgb_model_WI_2_28.bin
# [22 -> 28] predict 9/10 WI_2 day 22
# [22 -> 28] predict 9/10 WI_2 day 23
# [22 -> 28] predict 9/10 WI_2 day 24
# [22 -> 28] predict 9/10 WI_2 day 25
# [22 -> 28] predict 9/10 WI_2 day 26
# [22 -> 28] predict 9/10 WI_2 day 27
# [22 -> 28] predict 9/10 WI_2 day 28
# loading ../input/m5-train-day-1913-horizon-28/lgb_model_WI_3_28.bin
# [22 -> 28] predict 10/10 WI_3 day 22
# [22 -> 28] predict 10/10 WI_3 day 23
# [22 -> 28] predict 10/10 WI_3 day 24
# [22 -> 28] predict 10/10 WI_3 day 25
# [22 -> 28] predict 10/10 WI_3 day 26
# [22 -> 28] predict 10/10 WI_3 day 27
# [22 -> 28] predict 10/10 WI_3 day 28

# %%
submission = pd.read_csv("../input/m5-forecasting-accuracy/sample_submission.csv")

# %%
pred_v_all_df.d = pred_v_all_df.d - end_train_day_x_list
pred_h_all_df = pred_v_all_df.pivot(index='id', columns='d', values='sales')
pred_h_all_df = pred_h_all_df.reset_index()
pred_h_all_df.columns = submission.columns

# %%
submission = submission[['id']].merge(pred_h_all_df, on=['id'], how='left').fillna(0)
submission.to_csv("m5_predictions.csv", index=False)
